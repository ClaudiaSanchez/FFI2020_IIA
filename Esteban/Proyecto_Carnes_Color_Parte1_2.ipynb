# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import cv2
import os
import glob
from PIL import Image, ImageDraw, ImageFilter, ImageColor
from sklearn.cluster import KMeans
from sklearn.metrics import pairwise_distances_argmin_min
import math

# %% [markdown]
# #Análisis de círculos

# %%
Pal2 = cv2.imread("Int2.jpeg")
Pal2 = cv2.cvtColor(Pal2, cv2.COLOR_BGR2RGB)
#Pal2 = cv2.imread("WhatsApp Image 2020-10-21 at 3.05.03 PM.jpeg")

plt.figure()
plt.imshow(Pal2)
plt.show()

gray = cv2.cvtColor(Pal2, cv2.COLOR_RGB2GRAY)
img = cv2.medianBlur(gray, 5)

cimg = cv2.cvtColor(img, cv2.COLOR_GRAY2BGR)

circles = cv2.HoughCircles(img, cv2.HOUGH_GRADIENT,1,80,param1=100,param2=30,minRadius=50,maxRadius=100)
circles = np.uint16(np.around(circles))

crpi2 = []

for i in circles[0,:]:

  cv2.circle(Pal2, (i[0], i[1]), i[2], (0,0,0), 12)  
'''
  r=i[2]
  x=int(i[0]-r+r/3+r/10)
  y=int(i[1]-r+r/3+r/10)
  
  crpi2.append(Pal2[y:int((y+((r-r/3-r/15)*2))), x:int((x+(2*(r-r/3-r/15))))]) 
'''

plt.figure()
plt.imshow(Pal2)
plt.show()
'''
plt.figure()
plt.imshow(crpi2[0])
plt.show()
'''
# Out:
# '\nplt.figure()\nplt.imshow(crpi2[0])\nplt.show()\n'

# %%
Pal1 = cv2.imread("PalCol1.jpeg")
Pal1 = cv2.cvtColor(Pal1, cv2.COLOR_BGR2RGB)

gray = cv2.cvtColor(Pal1, cv2.COLOR_RGB2GRAY)
img = cv2.medianBlur(gray, 5)

cimg = cv2.cvtColor(img, cv2.COLOR_GRAY2RGB)
plt.figure()
plt.imshow(Pal1)
plt.show()
#circles = cv2.HoughCircles(img, cv2.HOUGH_GRADIENT,1,80,param1=100,param2=30,minRadius=20,maxRadius=50)
circles = cv2.HoughCircles(img, cv2.HOUGH_GRADIENT,1,80,param1=100,param2=30,minRadius=50,maxRadius=100)
circles = np.uint16(np.around(circles))

crpi1 = []
for i in circles[0,:]:

  cv2.circle(Pal1, (i[0], i[1]), i[2], (255,0,0), 8)  

  r=i[2]
  x=int(i[0]-r+r/3+r/10)
  y=int(i[1]-r+r/3+r/10)
  
  crpi1.append(Pal1[y:int((y+((r-r/3-r/15)*2))), x:int((x+(2*(r-r/3-r/15))))]) 


plt.figure()
plt.imshow(Pal1)
plt.show()
plt.figure()
plt.imshow(crpi1[0])
plt.show()

# %%
Pal2 = cv2.imread("PalCol2.jpeg")
#Pal2 = cv2.imread("WhatsApp Image 2020-10-21 at 3.05.03 PM.jpeg")
Pal2 = cv2.cvtColor(Pal2, cv2.COLOR_BGR2RGB) 
plt.figure()
plt.imshow(Pal2)
plt.show()

gray = cv2.cvtColor(Pal2, cv2.COLOR_RGB2GRAY)
img = cv2.medianBlur(gray, 5)

cimg = cv2.cvtColor(img, cv2.COLOR_GRAY2BGR)

circles = cv2.HoughCircles(img, cv2.HOUGH_GRADIENT,1,80,param1=100,param2=30,minRadius=50,maxRadius=100)
circles = np.uint16(np.around(circles))


crpi2 = []
for i in circles[0,:]:

  cv2.circle(Pal2, (i[0], i[1]), i[2], (255,0,0), 8)  

  r=i[2]
  x=int(i[0]-r+r/3+r/10)
  y=int(i[1]-r+r/3+r/10)
  
  crpi2.append(Pal2[y:int((y+((r-r/3-r/15)*2))), x:int((x+(2*(r-r/3-r/15))))]) 


plt.figure()
plt.imshow(Pal2)
plt.show()

plt.figure()
plt.imshow(crpi2[0])
plt.show()

# %% [markdown]
# #Muestra de los colores en una gráfica

# %%
plt.figure()
plt.imshow(Pal1)
plt.show()
plt.figure()
plt.imshow(Pal2)
plt.show()

Total1=[]


for cr in crpi1:
  nrows,ncols,nch = cr.shape
  Ximg = np.reshape(cr,(nrows*ncols,3))
  idx = np.random.permutation(len(Ximg))[:600]
  Ximg = Ximg[idx,:]

  for i in Ximg:
    Total1.append(i)


Total1=np.array(Total1)
idx = np.random.permutation(len(Total1))[:600]
Total1 = Total1[idx,:]
# print(len(Total1))

R1 = Total1[:,0]
G1 = Total1[:,1]
B1 = Total1[:,2]


fig = plt.figure()
ax = fig.gca(projection='3d')
ax.scatter(R1, G1, B1, c=Total1/255)
ax.set_xlim(0, 255)
ax.set_ylim(0, 255)
ax.set_zlim(0, 255)
ax.set_xlabel('RED')
ax.set_ylabel('GREEN')
ax.set_zlabel('BLUE')
plt.show()



Total2=[]



for cr in crpi2:
  nrows,ncols,nch = cr.shape
  Ximg = np.reshape(cr,(nrows*ncols,3))
  idx = np.random.permutation(len(Ximg))[:600]
  Ximg = Ximg[idx,:]

  for i in Ximg:
    Total2.append(i)


Total2=np.array(Total2)
idx = np.random.permutation(len(Total2))[:600]
Total2 = Total2[idx,:]
# print(len(Total2))

R2 = Total2[:,0]
G2 = Total2[:,1]
B2 = Total2[:,2]


fig = plt.figure()
ax = fig.gca(projection='3d')
ax.scatter(R2, G2, B2, c=Total2/255)
ax.set_xlim(0, 255)
ax.set_ylim(0, 255)
ax.set_zlim(0, 255)
ax.set_xlabel('RED')
ax.set_ylabel('GREEN')
ax.set_zlabel('BLUE')
plt.show()

# print(Total[0])

# %% [markdown]
# #Identifican los grupos de colores con kmeans

# %%
arrkmeans1 = [0 for i in range(17)]
auxkmeans1 = []
promkmeans1 = [[0,0,0] for i in range(17)]
promk1 = []
contkmeans1 = [0 for i in range(17)]

kmeans1 = KMeans(17).fit(Total1)
for i, l in enumerate(kmeans1.labels_):
  promkmeans1[l][0] += Total1[i][0]
  promkmeans1[l][1] += Total1[i][1]
  promkmeans1[l][2] += Total1[i][2]
  contkmeans1[l] += 1
  # print("({0},{1},{2}) en clase {3}".format(Total[i][0], Total[i][1], Total[i][2], l))
  if l not in auxkmeans1:
    auxkmeans1.append(l)
    arrkmeans1[l] = ([Total1[i][0],Total1[i][1],Total1[i][2]])
    #print("({0},{1},{2}) en clase {3}".format(Total[i][0], Total[i][1], Total[i][2], l))
arrkmeans1 = np.array(arrkmeans1)
for i in range(17):
  #print(promkmeans1[i][0])
  #promkmeans1[i] = (promkmeans1[i][0])/contkmeans1[i]
  promkmeans1[i][0] /= contkmeans1[i]
  promkmeans1[i][1] /= contkmeans1[i]
  promkmeans1[i][2] /= contkmeans1[i]
  promk1.append((promkmeans1[i][0]+promkmeans1[i][1]+promkmeans1[i][2])/3)
#print(promkmeans1)
#print(promk1)
'''
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.scatter(R1, G1, B1, c=Total1/255)
ax.set_xlim(0, 255)
ax.set_ylim(0, 255)
ax.set_zlim(0, 255)
ax.set_xlabel('RED')
ax.set_ylabel('GREEN')
ax.set_zlabel('BLUE')
plt.show()
# promkmeans = np.array(promkmeans)
# promkmeans = 
#print(promkmeans[0])
#print(arrkmeans)
'''
H1 = arrkmeans1[:,0]
S1 = arrkmeans1[:,1]
V1 = arrkmeans1[:,2]
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.scatter(H1, S1, V1, c=arrkmeans1/255)
ax.set_xlim(0, 255)
ax.set_ylim(0, 255)
ax.set_zlim(0, 255)
ax.set_xlabel('RED')
ax.set_ylabel('GREEN')
ax.set_zlabel('BLUE')
plt.show()

#-------------------------------------------------------------------------------

kmeans2 = KMeans(17).fit(Total2)
arrkmeans2 = [0 for i in range(17)]
auxkmeans2 = []
promkmeans2 = [[0,0,0] for i in range(17)]
promk2 = []
contkmeans2 = [0 for i in range(17)]

for i, l in enumerate(kmeans2.labels_):
  promkmeans2[l][0] += Total2[i][0]
  promkmeans2[l][1] += Total2[i][1]
  promkmeans2[l][2] += Total2[i][2]

  contkmeans2[l] += 1
  # print("({0},{1},{2}) en clase {3}".format(Total[i][0], Total[i][1], Total[i][2], l))
  if l not in auxkmeans2:
    auxkmeans2.append(l)
    arrkmeans2[l] = ([Total2[i][0],Total2[i][1],Total2[i][2]])
    #print("({0},{1},{2}) en clase {3}".format(Total[i][0], Total[i][1], Total[i][2], l))
arrkmeans2 = np.array(arrkmeans2)
for i in range(17):
  #promkmeans2[i] = (promkmeans2[i][0])/contkmeans2[i]
  promkmeans2[i][0] /= contkmeans2[i]
  promkmeans2[i][1] /= contkmeans2[i]
  promkmeans2[i][2] /= contkmeans2[i]
  promk2.append((promkmeans2[i][0]+promkmeans2[i][1]+promkmeans2[i][2])/3)
#print(promkmeans2)
#print(promk2)
'''
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.scatter(R2, G2, B2, c=Total2/255)
ax.set_xlim(0, 255)
ax.set_ylim(0, 255)
ax.set_zlim(0, 255)
ax.set_xlabel('RED')
ax.set_ylabel('GREEN')
ax.set_zlabel('BLUE')
plt.show()
# promkmeans = np.array(promkmeans)
# promkmeans = 
# print(promkmeans[0])
# print(arrkmeans)
'''
H2 = arrkmeans2[:,0]
S2 = arrkmeans2[:,1]
V2 = arrkmeans2[:,2]
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.scatter(H2, S2, V2, c=arrkmeans2/255)
ax.set_xlim(0, 255)
ax.set_ylim(0, 255)
ax.set_zlim(0, 255)
ax.set_xlabel('RED')
ax.set_ylabel('GREEN')
ax.set_zlabel('BLUE')
plt.show()

# %% [markdown]
# #Se determina que colores corresponden en ambas imágenes

# %%
index = 3
auxindex = 0
min = 1000000
actmin = 0
print("(",promkmeans1[index][0],", ",promkmeans1[index][1],", ",promkmeans1[index][2],")\n")
for i in range(17):
  actmin = abs(promkmeans1[index][0]-promkmeans2[i][0])+abs(promkmeans1[index][1]-promkmeans2[i][1])+abs(promkmeans1[index][2]-promkmeans2[i][2])
  print(str(i)+": (",abs(promkmeans1[index][0]-promkmeans2[i][0]),", ",abs(promkmeans1[index][1]-promkmeans2[i][1]),", ",abs(promkmeans1[index][2]-promkmeans2[i][2]),")")
  print("(",promkmeans2[i][0],", ",promkmeans2[i][1],", ",promkmeans2[i][2],")")
  print(actmin,"\n")
  if actmin < min:
    auxindex = i
    min = actmin
print(str(auxindex)+": ",min)
# Out:
# ( 62.89655172413793 ,  129.0 ,  104.27586206896552 )
#
# 0: ( 78.72844827586206 ,  47.30000000000001 ,  0.4241379310344797 )
# ( 141.625 ,  176.3 ,  104.7 )
# 126.45258620689656
#
# 1: ( 79.1304753028891 ,  72.35135135135135 ,  34.11369990680336 )
# ( 142.02702702702703 ,  56.648648648648646 ,  70.16216216216216 )
# 185.5955265610438
#
# 2: ( 136.79575596816974 ,  23.30769230769232 ,  82.80106100795754 )
# ( 199.69230769230768 ,  152.30769230769232 ,  187.07692307692307 )
# 242.9045092838196
#
# 3: ( 28.710591133004932 ,  39.89285714285714 ,  1.418719211822662 )
# ( 91.60714285714286 ,  89.10714285714286 ,  102.85714285714286 )
# 70.02216748768473
#
# 4: ( 115.38916256157634 ,  6.257142857142867 ,  22.475862068965526 )
# ( 178.28571428571428 ,  135.25714285714287 ,  81.8 )
# 144.12216748768475
#
# 5: ( 1.656079854809441 ,  14.65789473684211 ,  81.513611615245 )
# ( 64.55263157894737 ,  114.34210526315789 ,  185.78947368421052 )
# 97.82758620689654
#
# 6: ( 131.27487684729064 ,  66.08571428571429 ,  32.475862068965526 )
# ( 194.17142857142858 ,  62.91428571428571 ,  71.8 )
# 229.83645320197047
#
# 7: ( 137.3666061705989 ,  28.421052631578945 ,  40.539927404718696 )
# ( 200.26315789473685 ,  100.57894736842105 ,  144.81578947368422 )
# 206.32758620689657
#
# 8: ( 144.35344827586206 ,  80.32142857142858 ,  27.061576354679815 )
# ( 207.25 ,  209.32142857142858 ,  77.21428571428571 )
# 251.73645320197045
#
# 9: ( 61.233883058470774 ,  36.326086956521735 ,  49.28935532233882 )
# ( 124.1304347826087 ,  92.67391304347827 ,  153.56521739130434 )
# 146.84932533733132
#
# 10: ( 92.44827586206895 ,  49.79310344827587 ,  116.58620689655172 )
# ( 155.3448275862069 ,  178.79310344827587 ,  220.86206896551724 )
# 258.8275862068965
#
# 11: ( 4.015212981744419 ,  8.617647058823536 ,  4.841784989858013 )
# ( 66.91176470588235 ,  137.61764705882354 ,  109.11764705882354 )
# 17.474645030425968
#
# 12: ( 138.38469827586206 ,  31.71875 ,  26.161637931034477 )
# ( 201.28125 ,  160.71875 ,  130.4375 )
# 196.26508620689654
#
# 13: ( 151.83072100313478 ,  82.95454545454547 ,  120.04231974921629 )
# ( 214.72727272727272 ,  211.95454545454547 ,  224.3181818181818 )
# 354.8275862068965
#
# 14: ( 122.24978973927671 ,  50.07317073170731 ,  84.94365012615643 )
# ( 185.14634146341464 ,  179.0731707317073 ,  189.21951219512195 )
# 257.26661059714047
#
# 15: ( 138.67101584342964 ,  0.13513513513512976 ,  20.302889095992555 )
# ( 201.56756756756758 ,  128.86486486486487 ,  83.97297297297297 )
# 159.10904007455733
#
# 16: ( 125.59125315391086 ,  59.34146341463415 ,  8.349032800672845 )
# ( 188.4878048780488 ,  69.65853658536585 ,  95.92682926829268 )
# 193.28174936921783
#
# 11:  17.474645030425968

# %%
mtrx = [[] for _ in range(17)]
tabu = [0 for _ in range(17)]
res = [0 for _ in range(17)]

for index in range(17):
  auxindex = 0
  min = 1000000
  actmin = 0

  for i in range(17):
    actmin = abs(promkmeans1[index][0]-promkmeans2[i][0])+abs(promkmeans1[index][1]-promkmeans2[i][1])+abs(promkmeans1[index][2]-promkmeans2[i][2])
    mtrx[index].append(actmin)
    
    
  
for j in range(17):
  '''
  for _ in mtrx:
    for __ in _:
      print(__, end=" | ")
    print()
  print()
  '''
  min = 1000000
  
  for i in range(17):
    actmin = np.argmin(mtrx[i])
    
    if min > mtrx[i][actmin] and not tabu[i]:
      
      min = mtrx[i][actmin]
      col = actmin
      fil = i

  #En tabu se guarda 1 si ya se usó la fila
  tabu[fil] = 1
  
  #print("Min of "+str(fil)+":",min,col)
  res[fil] = col
  
  #print(tabu)
  for i in range(17):
    mtrx[i][col] = 1000000
print(res)
# Out:
# [6, 10, 3, 11, 8, 13, 12, 5, 16, 0, 2, 4, 1, 7, 9, 14, 15]

# %%
for i in range(17):
  
  arr = np.array([arrkmeans1[i], arrkmeans2[res[i]]])
  R = arr[:,0]
  G = arr[:,1]
  B = arr[:,2]
  fig = plt.figure()
  ax = fig.gca(projection='3d')
  ax.scatter(R, G, B, c=arr/255)
  ax.set_xlim(0, 255)
  ax.set_ylim(0, 255)
  ax.set_zlim(0, 255)
  ax.set_xlabel('RED')
  ax.set_ylabel('GREEN')
  ax.set_zlabel('BLUE')
  plt.show()

# %% [markdown]
# #Muestra finál de como se registraron los colores

# %%
#[arrkmeans1[i], arrkmeans2[res[i]]]
promkmeans22 = [[0,0,0] for i in range(17)]
for i in range(17):
  promkmeans22[i] = promkmeans2[res[i]]
im = Image.new('RGB', (100,50*17), (255,255,255)) # create the Image of size 1 pixel 
for _ in range(17):
  for i in range(40):
    for j in range(40):
      im.putpixel((5+i,5+j + (_*50)), (arrkmeans1[_][0],arrkmeans1[_][1],arrkmeans1[_][2]))
      im.putpixel((55+i,5+j + (_*50)), (arrkmeans2[res[_]][0],arrkmeans2[res[_]][1],arrkmeans2[res[_]][2]))
plt.figure()
plt.imshow(im)
plt.show()

# %%
from sklearn.linear_model import LinearRegression
model1 = LinearRegression()
model2 = LinearRegression()
model3 = LinearRegression()
promkmeans22 = np.array(promkmeans22)
promkmeans1 = np.array(promkmeans1)
model1.fit(promkmeans1,promkmeans22[:,0])
model2.fit(promkmeans1,promkmeans22[:,1])
model3.fit(promkmeans1,promkmeans22[:,2])
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
Pal2 = cv2.imread("PalCol1.jpeg")
Pal2 = cv2.cvtColor(Pal2, cv2.COLOR_BGR2RGB)
Pal2cpy = Pal2.copy()
nrows,ncols,_ = Pal2cpy.shape
Ximg = np.reshape( Pal2cpy, (nrows*ncols,3) )
Nimg = Ximg.copy()
Nimg[:,0] = model1.predict(Ximg)
Nimg[:,1] = model2.predict(Ximg)
Nimg[:,2] = model3.predict(Ximg)
nimg = np.reshape( Nimg, (nrows,ncols,3))

# %%
Pal1 = cv2.imread("PalCol1.jpeg")
Pal1 = cv2.cvtColor(Pal1, cv2.COLOR_BGR2RGB)
Pal1cpy = Pal1.copy()
nrows,ncols,_ = Pal1cpy.shape
Ximg = np.reshape( Pal1cpy, (nrows*ncols,3) )
meansEx2 = promkmeans22.copy()
meansEx2[:,0] = model1.predict(promkmeans1)
meansEx2[:,1] = model2.predict(promkmeans1)
meansEx2[:,2] = model3.predict(promkmeans1)
nimg = np.reshape( Nimg, (nrows,ncols,3))

# %%
means = promkmeans1.copy()
meansEx = promkmeans22.copy()
model1 = LinearRegression()
model2 = LinearRegression()
model3 = LinearRegression()
#print(np.concatenate((means,means**2,means**3),axis=1))
model1.fit(np.concatenate((np.concatenate((means,means**2),axis=1),means**3),axis=1),meansEx[:,0])
model2.fit(np.concatenate((np.concatenate((means,means**2),axis=1),means**3),axis=1),meansEx[:,1])
model3.fit(np.concatenate((np.concatenate((means,means**2),axis=1),means**3),axis=1),meansEx[:,2])

meansEx2 = meansEx.copy()
meansEx2[:,0] = model1.predict(np.concatenate((np.concatenate((means,means**2),axis=1),means**3),axis=1))
meansEx2[:,1] = model2.predict(np.concatenate((np.concatenate((means,means**2),axis=1),means**3),axis=1))
meansEx2[:,2] = model3.predict(np.concatenate((np.concatenate((means,means**2),axis=1),means**3),axis=1))

# %%
plt.figure()
plt.imshow(Pal2)
plt.show()
plt.figure()
plt.imshow(nimg)
plt.show()
